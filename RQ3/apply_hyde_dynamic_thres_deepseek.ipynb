# %% [markdown]
# # DeepSeek Dynamic Threshold Application
# This notebook applies dynamic threshold selection and generates answers using the DeepSeek API.

# %%
import pandas as pd
import os
import time
import re

# Load threshold CSV files
threshold1 = pd.read_csv('sythetic_testing/RAG4_0.5.csv')
threshold2 = pd.read_csv('sythetic_testing/RAG4_0.6.csv')
threshold3 = pd.read_csv('sythetic_testing/RAG4_0.7.csv')
threshold4 = pd.read_csv('sythetic_testing/RAG4_0.8.csv')
threshold5 = pd.read_csv('sythetic_testing/RAG4_0.9.csv')

# %%
# Function to check if the CONTEXT is empty
def is_context_empty(cell_text):
    match = re.search(r"### CONTEXT:\s*(\[\s*\])", cell_text)
    return bool(match)  # True if context is exactly "[]", False otherwise

# Add context-empty flags to each threshold DataFrame
threshold5['Context_Empty_0.9'] = threshold5['Prompt'].apply(is_context_empty)
threshold4['Context_Empty_0.8'] = threshold4['Prompt'].apply(is_context_empty)
threshold3['Context_Empty_0.7'] = threshold3['Prompt'].apply(is_context_empty)
threshold2['Context_Empty_0.6'] = threshold2['Prompt'].apply(is_context_empty)
threshold1['Context_Empty_0.5'] = threshold1['Prompt'].apply(is_context_empty)

# %%
threshold1['Context_Empty_0.5'].value_counts()
# Out:
# Context_Empty_0.5
# False    385
# Name: count, dtype: int64

# %%
# Aggregate prompts and context flags into a single DataFrame
dataset_generation = threshold1[['Question']].copy()
dataset_generation['Prompt_0.5'] = threshold1['Prompt']
dataset_generation['Prompt_0.6'] = threshold2['Prompt']
dataset_generation['Prompt_0.7'] = threshold3['Prompt']
dataset_generation['Prompt_0.8'] = threshold4['Prompt']
dataset_generation['Prompt_0.9'] = threshold5['Prompt']
dataset_generation['Context_Empty_0.5'] = threshold1['Context_Empty_0.5']
dataset_generation['Context_Empty_0.6'] = threshold2['Context_Empty_0.6']
dataset_generation['Context_Empty_0.7'] = threshold3['Context_Empty_0.7']
dataset_generation['Context_Empty_0.8'] = threshold4['Context_Empty_0.8']
dataset_generation['Context_Empty_0.9'] = threshold5['Context_Empty_0.9']

# %%
# Select the final prompt for each row based on context availability
def choose_final_Prompt(row):
    if not row['Context_Empty_0.9']:
        return row['Prompt_0.9']
    elif not row['Context_Empty_0.8']:
        return row['Prompt_0.8']
    elif not row['Context_Empty_0.7']:
        return row['Prompt_0.7']
    elif not row['Context_Empty_0.6']:
        return row['Prompt_0.6']
    else:
        return row['Prompt_0.5']
dataset_generation['final_prompt'] = dataset_generation.apply(choose_final_Prompt, axis=1)

# %%
import requests

DEEPSEEK_API_URL = ""
DEEPSEEK_MODEL = "deepseek-r1:70b"
DRY_RUN = False  # Set to False to enable real API calls

class DeepSeekClient:
    def __init__(self, api_url, model):
        self.api_url = api_url
        self.model = model
    def generate(self, prompt, max_tokens=512, temperature=0.7, top_p=0.9):
        if DRY_RUN:
            return f"[DRY_RUN] Answer for: {prompt}"
        data = {
            "model": self.model,
            "prompt": prompt,
            "stream": False
        }
        response = requests.post(self.api_url, json=data)
        return response.json().get("response", "")

client = DeepSeekClient(DEEPSEEK_API_URL, DEEPSEEK_MODEL)

# %%
# Generate DeepSeek responses for each final prompt
from tqdm import tqdm
response_list = []
for prompt in tqdm(dataset_generation['final_prompt'], desc='DeepSeek Generating'):
    answer = client.generate(prompt)
    response_list.append(answer)
dataset_generation['deepseek_output'] = response_list
# Out:
# DeepSeek Generating: 100%|██████████| 385/385 [9:54:29<00:00, 92.65s/it]

# %%
print(response_list[0])
# Out:
# <think>
# Okay, so I'm trying to set up grunt-browser-sync in my Cloud9 development environment. I've been having some trouble getting it running properly. Let me go through the steps and see where I might be going wrong.
#
# First, I remember that I need to install the necessary npm packages. Grunt itself is required, along with browser-sync and any other plugins I might need like grunt-contrib-uglify for minifying JavaScript files. So, I'll start by installing them using npm:
#
# npm install grunt grunt-browser-sync grunt-contrib-uglify --save-dev
#
# Next, I need to make sure my package.json file includes these as devDependencies. That way, anyone else working on the project or when deploying, they can run npm install and get all the necessary packages.
#
# Now, onto the Gruntfile. I think I might have made a mistake in setting up the tasks. Let me check my current Gruntfile.js. Oh, wait, I see that I only registered 'concat' and 'uglify' as default tasks but didn't include browser-sync. That's probably why it's not running.
#
# I need to add the browserSync task configuration. From what I recall, the basic setup involves specifying the server and which files to watch. So in my Gruntfile, under grunt.initConfig, I'll add a browserSync section:
#
# browserSync: {
#     dev: {
#         bsFiles: {
#             src: [
#                 'app/Resources/app/src/*.js',
#                 'web/css/app.css'
#             ]
#         },
#         options: {
#             server: './web', // or wherever your static files are
#             watchTask: true
#         }
#     }
# }
#
# Then, I need to make sure this task is registered. Since I want browser-sync to run automatically whenever there's a change, I should set up a watch task that triggers both the build and refreshes the browser.
#
# So I'll add a watch configuration:
#
# watch: {
#     scripts: {
#         files: ['app/Resources/app/src/**/*.js'],
#         tasks: ['concat', 'uglify', 'browserSync']
#     },
#     css: {
#         files: ['web/css/*.css'],
#         tasks: ['browserSync']
#     }
# }
#
# Wait, no. Actually, the watch task should run browserSync only if it's already running. Maybe I'm overcomplicating this. Perhaps I should create a separate task for starting the server and another for watching.
#
# I think the correct approach is to have a 'serve' task that starts the browser-sync server and watches for changes. So, I'll register two tasks: one for building (concat and uglify) and another for serving which includes watch.
#
# So in my Gruntfile, after defining all the configurations, I'll add:
#
# grunt.registerTask('default', ['build']);
# grunt.registerTask('serve', ['build', 'browserSync', 'watch']);
#
# This way, when I run 'grunt serve', it will build the files, start browser-sync, and then watch for any changes to re-build and refresh.
#
# I also need to make sure that all the necessary grunt plugins are loaded. So at the end of my Gruntfile, after registering tasks, I'll add:
#
# grunt.loadNpmTasks('grunt-contrib-concat');
# grunt.loadNpmTasks('grunt-contrib-uglify');
# grunt.loadNpmTasks('browser-sync');
# grunt.loadNpmTasks('grunt-contrib-watch');
#
# Wait, but in newer versions, sometimes you can use load-grunt-tasks to automatically load all plugins. Maybe that's why it wasn't working before because I forgot to load a plugin.
#
# So I'll install load-grunt-tasks:
#
# npm install load-grunt-tasks --save-dev
#
# Then, at the top of my Gruntfile, require it:
#
# module.exports = function(grunt) {
#     require('load-grunt-tasks')(grunt);
#     // rest of the configuration
# };
#
# This should eliminate the need to manually load each npm task.
#
# Putting it all together, my Gruntfile.js should now have:
#
# - The package.json with correct devDependencies.
# - Proper configurations for concat, uglify, browserSync, and watch.
# - Tasks registered correctly so that 'grunt serve' runs build, starts server, and watches.
#
# I'll test this by running 'grunt serve' in the terminal. If everything is set up right, it should open a browser window with my app and automatically refresh when I make changes to JS or CSS files.
#
# If I encounter any issues like 'grunt: command not found', I might need to install grunt-cli globally:
#
# npm install -g grunt-cli
#
# And if Cloud9 has any specific setup for Node.js versions, I can check by running nodejs --version and npm --version to ensure they're up-to-date.
# </think>
#
# To set up `grunt-browser-sync` in your Cloud9 environment, follow these organized steps:
#
# ### Step 1: Install Dependencies
#
# Install the necessary npm packages. Run the following command in your terminal:
#
# ```bash
# npm install grunt grunt-browser-sync grunt-contrib-uglify load-grunt-tasks --save-dev
# ```
#
# This installs Grunt, BrowserSync, Uglify, and a helper to load tasks automatically.
#
# ### Step 2: Update package.json
#
# Ensure `package.json` includes these devDependencies. If not present, create one or edit it manually:
#
# ```json
# {
#     "name": "yourproject",
#     "version": "0.1.0",
#     "devDependencies": {
#         "grunt": "^0.4.5",
#         "grunt-browser-sync": "~2.0.0",
#         "grunt-contrib-uglify": "~0.11.0",
#         "load-grunt-tasks": "~0.4.0"
#     }
# }
# ```
#
# Run `npm install` to install all dependencies.
#
# ### Step 3: Configure Gruntfile.js
#
# Create or update your `Gruntfile.js` with the following content:
#
# ```javascript
# module.exports = function(grunt) {
#     require('load-grunt-tasks')(grunt); // Automatically load grunt tasks
#
#     grunt.initConfig({
#         pkg: grunt.file.readJSON('package.json'),
#
#         // Concatenate JavaScript files
#         concat: {
#             dist: {
#                 src: ['app/Resources/app/src/*.js', 'app/Resources/app/src/**/*.js'],
#                 dest: 'web/app/js/app.js'
#             }
#         },
#
#         // Minify concatenated JS file
#         uglify: {
#             app: {
#                 src: ['web/app/js/app.js'],
#                 dest: 'web/app/js/app-min.js'
#             }
#         },
#
#         // BrowserSync configuration
#         browserSync: {
#             dev: {
#                 bsFiles: {
#                     src: [
#                         'app/Resources/app/src/*.js',
#                         'web/css/app.css'
#                     ]
#                 },
#                 options: {
#                     server: './web', // Adjust based on your project structure
#                     watchTask: true
#                 }
#             }
#         },
#
#         // Watch for changes and run tasks
#         watch: {
#             scripts: {
#                 files: ['app/Resources/app/src/**/*.js'],
#                 tasks: ['concat', 'uglify']
#             },
#             css: {
#                 files: ['web/css/*.css'],
#                 options: {
#                     livereload: true
#                 }
#             }
#         }
#     });
#
#     // Register tasks
#     grunt.registerTask('default', ['build']);
#     grunt.registerTask('build', ['concat', 'uglify']);
#     grunt.registerTask('serve', ['build', 'browserSync', 'watch']);
# };
# ```
#
# ### Step 4: Run Grunt Tasks
#
# Execute the following command in your terminal to start the server and watch for changes:
#
# ```bash
# grunt serve
# ```
#
# This will:
# 1. Concatenate JavaScript files.
# 2. Minify them.
# 3. Start a BrowserSync server.
# 4. Watch for file changes and refresh automatically.
#
# ### Additional Notes:
#
# - Ensure you have `nodejs` and `npm` installed correctly in Cloud9. If not, use the chris-lea PPA to install Node.js.
#
#   ```bash
#   sudo add-apt-repository ppa:chris-lea/node.js
#   sudo apt-get update
#   sudo apt-get install nodejs npm
#   ```
#
# - Install `grunt-cli` globally for the `grunt` command:
#
#   ```bash
#   npm install -g grunt-cli
#   ```
#
# By following these steps, you should have `grunt-browser-sync` running smoothly in your Cloud9 environment.

# %%
# Save results to CSV
output_path = 'dynamic_RAG4_deepseek_results.csv'
dataset_generation.to_csv(output_path, index=False)
print(f"Saved to {output_path}")
# Out:
# Saved to dynamic_RAG4_deepseek_results.csv
